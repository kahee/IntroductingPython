# %%
def selection(list):
    length = len(list)
    
    for i in range(length-1):
        min_index = i
        
        for j in range(i+1, length):
            if list[min_index] > list[j]:
                min_index = j
            list[min_index], list[i] = list[i], list[min_index]
    return list

del bubble(list):
    length = len(list)
    
    for i in range(length-1,0,-1):
        for j in range(i):
            if list[j]>list[j+1]:
                list[j],list[j+1] = list[j+1], list[j]
                
    return list


def insertion(list):
    length = len(list)
    
    for i in range(1,length):
        curr_value = list[i]
        index = i
        
        while index > 0 and index[index-1]>index[curr_value]:
            list[index] = list[index-1]
            index -=1 
            
        list[index] = curr_value
        
    return list

# %%
# selection sort 
num = [5,1,4,7,2,6,8,3] 

import random 

def selection(list):
    lenth = len(list)
    print(lenth)
    
    for i in range(lenth-1):
        print(i)
        min_index=i
        for j in range(i+1, lenth):
            if list[min_index] > list[j]:
                min_index = j
            if i != min_index:
                list[min_index], list[i] = list[i], list[min_index]
                
        print(list)
    return list

selection(num)
# Out:
# 8
# 0
# [1, 5, 4, 7, 2, 6, 8, 3]
# 1
# [1, 3, 4, 7, 5, 6, 8, 2]
# 2
# [1, 3, 2, 7, 5, 6, 8, 4]
# 3
# [1, 3, 2, 4, 7, 6, 8, 5]
# 4
# [1, 3, 2, 4, 5, 6, 8, 7]
# 5
# [1, 3, 2, 4, 5, 6, 8, 7]
# 6
# [1, 3, 2, 4, 5, 6, 7, 8]
# [1, 3, 2, 4, 5, 6, 7, 8]

# %%
num = [5,1,4,7,2,6,8,3] 

def bubble(list):
    lenth = len(list)-1
    
    for i in range(lenth,0,-1):
        for j in range(i):
            if list[j]>list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]
    return list

bubble(num)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
num = [5,1,4,7,2,6,8,3]

def insertion(list):
    length = len(list)
    
    for i in range(1, length):
        curr_value = list[i]
        index = i 
        print(f'index= {index}')
        while index > 0 and list[index-1] > curr_value:
                list[index] = list[index-1]
                print(list)
                
                index -=1
                print(f'index= {index}')
        list[index] = curr_value
        print('ㄲ')
    return list

insertion(num)
# Out:
# index= 1
# [5, 5, 4, 7, 2, 6, 8, 3]
# index= 0
# ㄲ
# index= 2
# [1, 5, 5, 7, 2, 6, 8, 3]
# index= 1
# ㄲ
# index= 3
# ㄲ
# index= 4
# [1, 4, 5, 7, 7, 6, 8, 3]
# index= 3
# [1, 4, 5, 5, 7, 6, 8, 3]
# index= 2
# [1, 4, 4, 5, 7, 6, 8, 3]
# index= 1
# ㄲ
# index= 5
# [1, 2, 4, 5, 7, 7, 8, 3]
# index= 4
# ㄲ
# index= 6
# ㄲ
# index= 7
# [1, 2, 4, 5, 6, 7, 8, 8]
# index= 6
# [1, 2, 4, 5, 6, 7, 7, 8]
# index= 5
# [1, 2, 4, 5, 6, 6, 7, 8]
# index= 4
# [1, 2, 4, 5, 5, 6, 7, 8]
# index= 3
# [1, 2, 4, 4, 5, 6, 7, 8]
# index= 2
# ㄲ
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
def insertion(list):
    
    length = len(list)
    
    for i in rnage(1, length):
        curr_value = list[i]
        index = i
        
        while index > 0 and list[index-1] > curr_value:
            list[index] = list[index-1]
            index -=1
        
        list[index] = curr_value

# %%
def selection(list):
    
    length = len(list)
    
    for i in range(length-1):
        min_value = i
        for j in range(i+1, length):
            if list[min_value] > list[j]:
                min_value = j  
            list[min_index], list[i] = list[i], list[min_index]
    return list

# %%
def bubble(list):
    length = len(list)-1
    
    for i in range(length,0,-1):
        for j in range(i):
            if list[j] > list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]
    return list

# %%
def add_all(n):
    sum = 0
    for i in range(n+1):
        sum = sum + i
    return sum

add_all(3)
# Out:
# 6

# %%
def calc_num(num):
    if num == 1:
        return num
    return num+calc_sum(num-1)

# %%
def fib(index):
    if index < 2:
        return index

# %%
# 피보나치 수열

def fibonacci(index):
    if index < 2:
        return index
    return fibonacci(index-1) + fibonacci(index-2)

def fibonacci_con_recuresive(index):
    if index < 2:
        return index
    
    value = 1
    prev1 = 1
    prev2 = 1
    
    for i in range(index - 2):
        value = prev1+prev2
        prev2 = prev1
        prev1 = value 
    
    return value 

# 다이나믹 프로그래밍
# 메모리 할당
men = [0] * 101

def fibonacci_dynamic(index):
    if index < 2:
        return index 
    
    if men[index]:
        return men[index]
    
    else:
        men[index] = fibonacci_dynamic(index-1)+fibonacci_dynamic(index-2)
        return men[index]

# %%
mem = [0] * 101  # index 번째 피보나치 수열 저장소

def fibonacci_dynamic(index):  # 다이나믹 프로그래밍으로
   if index < 2:
       return index

   # mem 리스트의 인덱스 : index - 2도 가능 - 1, 2번째 리스트는 그냥 리턴하기 때문에 저장안되기 때문에...

   if mem[index]:  # 피보나치 수열을 이미 계산했다면...
       return mem[index]
   else:  # 계산한 피보나치 수열이 아니에요...
       mem[index] = fibonacci_dynamic(index - 1) + fibonacci_dynamic(index - 2)  # 값 계산해서 리스트에 저장해놓고
       return mem[index]  # 리턴하기


print("--- START ---")
start_time = time.time()
print(fibonacci_dynamic(40))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- START ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a2e5bbd2874> in <module>()
#      16
#      17 print("--- START ---")
# ---> 18 start_time = time.time()
#      19 print(fibonacci_dynamic(40))
#      20 print("--- %s seconds ---" % (time.time() - start_time))
#
# NameError: name 'time' is not defined

# %%
# quick_sort_easy()
# 파이썬을 이용하여 정통 퀵정렬은 아님
# 매개변수로 받은 list를 사용하는 것이 아니라 새로운 list를 생성하기 때문에 
# 메모리 문제가 있다.
def quick_sort_pythonic(list):
#   재귀 함수의 종료 조건을 항상 먼저 쓴다.
    if len(list)<=1:
        return list
    else:
#         피봇은 맨 앞 숫자 (*임의로 정의)
        pivot = list[0]
#     피봇보다 작은 숫자들 모음
        less = [i for i in list[1:] if i <= pivot]
#   피봇보다 큰 숫자들 모임
        greater = [i for i in list[1:] if i > pivot]
#       재귀호출 
        return quick_sort_pythonic(less) + [pivot] + quick_sort_pythonic(greater)

# %%
# 별도의 리스트를 사용하지 않고 어떻게 정렬할 수 잇을까?

# partition() : 피봇을 정하고, 피봇에 따라 작은 수, 큰수로 분류 후, 피봇의 원래 자리를 리턴
def partition(list, start,end):
#     피봇값 설정 
    pivot = list[start]
#     앞에서부터 뒤로 가면서 pivot보다 큰 값을 찾아갈 index
    left = start + 1
#     뒤에서부터 앞으로 오면서 pivot 보다 작은 값을 찾아갈 index
    right = end
#     pivot기준으로 분류가 다 되었는지 확인하는지 flag
#     분류가 어떻게 다 되었는지 아는가? right과 left가 교차할때 
    done = False
    
    while not done :
#         left는 큰 값의 인덱스를 찾는다.
        while left <= right and list[left]<=pivot:
#         작은 값을 찾으면 그다음으로 넘어간다.
            left += 1 
        while left <= right and list[right] > pivot:
            right-=1
        if left > right:
            done = True
        else:
#             분류가 안끝났으면  swap 
            list[right], list[left]= list[left], list[right]
# 분류 끝, 피봇을 제자리로 !!!!! 피봇은 작은 값들의 인덱스 중에서 가장 큰 값과 바꾸면 된다. 
        list[start], list[right] = list[right], list[start]
#     파티션의 마지막 임무 - 피봇 인덱스 넘기기 
        return right 
    
    
# quick_sort_classic()
def quick_sort_classic(list,start,end):
#  재귀함수 종료조건
    if start > end:
        return list
    else:
#       제자리를 찾은 피봇의 인덱스를 partition에게 받는다.
        pivot = partition(list, start, end)
#         피봇보다 작은 것
        quick_sort_classic(list,start, pivot -1)
#         피봇보다 큰 것 
        quick_sort_classic(list,pivot+1, end)
#     모든 정렬 마치고 리턴
    return list



# quick_sort_classic(numbaser, 0, len(numbers-1))
# 파티션이 얼마나 둘로 잘 쪼개느나냐가 bast케이스 worst의 경우 한쪽만 움직이는 것 - 완전히 역순이거나, 정렬이되어있거나 n^2
# 시간복잡도 앤로그앤 
# 캐시메모리쪽에서 사용하기 때문에 빠르다.

# %%
def quick_sort_classic(list, start, end):
    if start > end:
        return list
    else:
        pivot = partition(list,start,end)
        quick_sort_classic(list,start,pivot-1)
        quick_sort_classic(list,pivot+1, end)
        
    return list

def partition(list,start,end):
    pivot = list[start]
    left = start + 1
    right = end
    done = False
    
    while not done:
        while left <= right and list[left] <= pivot:
            left +=1
            
        while left <= right and list[right] > pivot:
            right -=1
        if left > right:
            done = True
        else:
            list[right], list[left] = list[left], list[right]
        
        list[start], list[right] = list[right], list[start]
        return right

# %%
def quick_sort(list,strat,end):
#   더 이상 비교할 대상이 없을 경우
    if start > end:
        return list
    
    else:
        pivot = partition(list, start, end)
        quick_sort(list,start, pivot-1)
        quick_sort(list,privot+1, end)
        
    return list


def partition(list, start, end):
    pivot = list[start]
#     pivot보다 큰값을 찾을때
    left = start +1
    # pivot 보다 작은 값을 찾을 때
    right = end 
    done = False
    
    while not done:
        while left <= right and list[left] <= pivot:
            left +=1
            
        while left <= right and list[right] > pivot:
            right -=1
            
        if left > right :
            done = True
        else:
            list[right], list[left] = list[left], list[right]
            
            
            
def quick_sort(list, start, end):
    if start > end:
        return start
    else:
        pivot = partition(list, start, end)
        quick_sort(list, start, pivot-1)
        quick_sort(list, pivot+1, start)
    return list

def partition(list, start, end):
    pivot = list[start]
    left = start +1
    right = end
    
    done = False
    
    while not done:
        while left <= right and list[left] <= pivot:
            left +=1
            
        while left <= right and list[right] > pivot:
            right -=1
            
        if left > right :
            done = True
        else:
            list[right], list[left] = list[left], list[right]
        
        
        list[start], list[right] = list[right], list[start]
        
        return right 
    
    
def selection_sort(list):
    length = len(list-1)
    
    for i in range(length):
        min_index = i 
        
        for j in range(i+1, length):
            if list[min_index] > list[j]:
                min_index = j
            list[min_index], list[i] = list[i], list[min_index]
        
        return list
    

            
def bubble(list):
    length = len(list)
    
    for i in range(length, 0, -1):
        for j in range(i):
            if list[j] > list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]
                
    return list

d
def insertion(list):
    length = len(list)
    
    for i in range(1, length):
        curr_value = list[i]
        index = i
        
        while index > 0 and list[index-1] > curr_value:
            list[index] = list[index-1]
            index -=1 
            
        list[index] = curr_value
        
    return list


def quick_sort(list, start, end):
    if start > end:
        return list
    
    else:
        pivot = partition(list, start, end)
        quick_sort(list, start, pivot-1)
        quick_sort(list, pivot+1, end)
        
    return list


def partition(list, start, end):
    pivot = list[start]
    left = start +1
    right = end
    done = False
    
    while not done:
        while left <= right and list[left]<= pivot:
            left +=1
            
        while left <= right and list[right] > pivot:
            right-=1
            
        if left > right :
            done = True
            
        else:
            list[right], list[left] = list[left], list[right]
            
        list[start], list[right] = list[right], list[start]
    
    
        return right
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75e50b87f8ed> in <module>()
#      93     return list
#      94
# ---> 95 d
#      96 def insertion(list):
#      97     length = len(list)
#
# NameError: name 'd' is not defined

# %%
# 1. divide and conquer 
# merge_sort

def merge_sort(list):
    length = len(list)
#     divide 해야 하는 상황
    if length > 1:
#         리스트를 반토막으로 자르기 
        mid = length//2
        left_list = list[:mid]
        right_list = list[mid:]
        
#         length == 1일때까지 재귀적으로 자른다. 
        merge_sort(left_list)
        merge_sort(right_list)
        
#         divide 가 마친 후 정렬(conquer)
        i = 0 #left_list에서 쓸 인덱스
        j = 0 #right_list 에서 쓸 인덱스 
        k = 0 #list에서 쓸 인덱스 
        
#         반토막낸 리스트들의 len 
        length_left = len(left_list)
        length_right = len(right_list)
        
#         아직 리스트에 정렬하지 않은 항목이 남아있으면
        while i < length_left and j < length_right:
            if left_list[i] < right_list[j]:
                list[k] = left_list[i]
                i +=1
                k +=1
            else:
                list[k] = right_list[j]
                j += 1
                k += 1
                
# 남은 숫자들을 정리하는 것 
        while i < length_left:
            list[k] = left_list[i]
            i +=1
            k +=1
            
        while j < length_right:
            list[k] = right_list[j]
            j += 1
            k += 1

                
    return list
# nlog(n)
# 별도 리스트를 만들기 때문에 공간복잡도O(n)
# Timsort() - 적당히 작은 단위로 나눔  : 캐시메모리안에서 정리 될 수 있게끔 -> 작은 단위의 리스트에서는 삽입 정렬을 진행함 (삽입 + 병합 정렬)
